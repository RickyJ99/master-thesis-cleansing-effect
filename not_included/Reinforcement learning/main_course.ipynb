# %% [markdown]
# # Import dependencies

# %%
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: gymnasium==0.28.1 in /usr/local/lib/python3.11/site-packages (from stable-baselines3) (0.28.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/site-packages (from stable-baselines3) (1.24.3)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.11/site-packages (from stable-baselines3) (2.0.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/site-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from stable-baselines3) (2.0.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/site-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.11/site-packages (from gymnasium==0.28.1->stable-baselines3) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/site-packages (from gymnasium==0.28.1->stable-baselines3) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium==0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from torch>=1.11->stable-baselines3) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/site-packages (from torch>=1.11->stable-baselines3) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch>=1.11->stable-baselines3) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch>=1.11->stable-baselines3) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/riccardodalcero/Library/Python/3.11/lib/python/site-packages (from matplotlib->stable-baselines3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/riccardodalcero/Library/Python/3.11/lib/python/site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->stable-baselines3) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/site-packages (from pandas->stable-baselines3) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/riccardodalcero/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch>=1.11->stable-baselines3) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/site-packages (from sympy->torch>=1.11->stable-baselines3) (1.3.0)

# %% [markdown]
# # Load Enviroment

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# 2023-08-17 15:52:51.328043: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Environments

# %%
environment_name    = 'CartPole-v1'                 #case-sensitive
env                 = gym.make(environment_name, render_mode="rgb_array")    #making the env

# %% [markdown]
# # Understanding the environment
# Episodes = Think of an episode as one full game within the environment.

# %%
episodes    =   5   # test five times 
for episode in range(1, episodes + 1):
    state   = env.reset()
    done    = False
    score   = 0
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info, info1 = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:43.0
# Episode:2 Score:43.0
# Episode:3 Score:24.0
# Episode:4 Score:22.0
# Episode:5 Score:17.0

# %% [markdown]
# # Training

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/site-packages (0.15.2)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/site-packages (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from torchvision) (2.29.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
log_path = os.path.join('Traning','Logs')
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cpu device
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps = 20000)
# Out:
# Logging to Traning/Logs/PPO_1
# /usr/local/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -----------------------------
# | time/              |      |
# |    fps             | 1768 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009237312 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0155     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.16        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 51.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1181        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009892402 |
# |    clip_fraction        | 0.0726      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0783      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 38.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1138         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0097847795 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.637       |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0172      |
# |    value_loss           | 51.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1114         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0068778247 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.622       |
# |    explained_variance   | 0.271        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0136      |
# |    value_loss           | 60.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1104         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0058902567 |
# |    clip_fraction        | 0.0775       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 0.505        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.86         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 56.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1097         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0070159137 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.368        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.4         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 83.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1091         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0078064874 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.4         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 55.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010114835 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 50.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1084         |
# |    iterations           | 10           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0058390726 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.6          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.009       |
# |    value_loss           | 27.6         |
# ------------------------------------------

# %% [markdown]
# # Save and reload

# %%
PPO_Path = os.path.join('Traning', 'Saved Models', 'PPO_Model_Cartpole')

#saving model
model.save(PPO_Path)

del model #delete model

#reloading 
model = PPO.load(PPO_Path, env = env)

model.learn(total_timesteps=1000)

# %% [markdown]
# # Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (475.2, 38.26173022747403)

# %% [markdown]
# # Test Model

# %%
episode = 5
for episode in range(1, episodes):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(obs) #Using model here
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:234: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Episode:1 Score:[435.]
# Episode:2 Score:[500.]
# Episode:3 Score:[500.]
# Episode:4 Score:[319.]

# %% [markdown]
# # View logs

# %%
traning_log_path = os.path.join(log_path,'PPO_1')

# !tensorboard --logdir={traning_log_path}
# Out:
# 2023-08-18 11:48:48.467644: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.13.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# # Adding a callback to traning Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
stop_callback = StopTrainingOnRewardThreshold(reward_threshold = 200, verbose = 1)
eval_callback = EvalCallback(env,
                            callback_on_new_best = stop_callback,
                            eval_freq = 1000,
                            best_model_save_path = 'Traning/Saved Models',
                            verbose = 1)
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
model.learn(total_timesteps=2000, callback=eval_callback)
# Out:
# Using cpu device
# Logging to Traning/Logs/PPO_2
# Eval num_timesteps=1000, episode_reward=31.20 +/- 10.46
# Episode length: 31.20 +/- 10.46
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 31.2     |
# |    mean_reward     | 31.2     |
# | time/              |          |
# |    total_timesteps | 1000     |
# ---------------------------------
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=31.60 +/- 4.67
# Episode length: 31.60 +/- 4.67
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 31.6     |
# |    mean_reward     | 31.6     |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 1548 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------

# %% [markdown]
# # Changing Policies

# %%
#New neural network
new_arch = [dict(pi=[128,128,128,128], vf = [128,128,128,128])] #4 layers with 128 elements
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':new_arch})
model.learn(total_timesteps=20000, callback = eval_callback)
# Out:
# Using cpu device
# Logging to Traning/Logs/PPO_3
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/policies.py:460: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Eval num_timesteps=952, episode_reward=8.60 +/- 0.49
# Episode length: 8.60 +/- 0.49
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 8.6      |
# |    mean_reward     | 8.6      |
# | time/              |          |
# |    total_timesteps | 952      |
# ---------------------------------
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=1952, episode_reward=8.80 +/- 0.40
# Episode length: 8.80 +/- 0.40
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 8.8      |
# |    mean_reward     | 8.8      |
# | time/              |          |
# |    total_timesteps | 1952     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 1550 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=2952, episode_reward=375.80 +/- 109.29
# Episode length: 375.80 +/- 109.29
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 376         |
# |    mean_reward          | 376         |
# | time/                   |             |
# |    total_timesteps      | 2952        |
# | train/                  |             |
# |    approx_kl            | 0.015256573 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.00128    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 17.4        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 375.80  is above the threshold 200

# %%
#Using an Alternate algh
from stable_baselines3 import DQN
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
model.learn(total_timesteps=20000)
# Out:
# Using cpu device
# Logging to Traning/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3077     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 74       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5089     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5477     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 304      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5694     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 369      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 6176     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 491      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 6210     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 579      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 6136     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 641      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.659    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 6222     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 717      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 6242     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 799      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 6283     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 897      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 6408     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 978      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 6545     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 6610     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.412    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 6522     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 6669     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 6561     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1412     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.287    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 6551     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 6455     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1568     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.208    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 6509     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 6524     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.131    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 6480     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0742   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 6457     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 6467     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 6538     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6573     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 6586     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 6632     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 6704     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 6694     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 6719     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 6727     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 6775     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2715     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 6803     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2786     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 6881     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 6918     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2955     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 6959     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 6968     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 6981     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 7041     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 7040     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 7043     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3413     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 7064     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 7093     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 7150     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 7181     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3786     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 7211     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 7230     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 7263     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 7290     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4178     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 7306     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 7331     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 7360     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 7369     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 7351     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 7061     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 6791     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 6769     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 6759     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5065     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 6741     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 6724     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 6749     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5411     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 6761     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5548     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 6637     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 6597     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 6631     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 6633     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 6691     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 6670     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 6659     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 6680     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 6684     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 6710     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 6742     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 6759     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6721     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 6768     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 6777     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 6794     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 6818     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 6817     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 6826     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7177     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 6843     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 6852     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 6889     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 6897     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 6903     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 6911     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 6914     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 6899     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 6926     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 6945     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 6965     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 6976     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 7002     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 7019     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 7035     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 7052     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 7081     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 7107     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 7129     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 7135     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 7166     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 7169     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 7195     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 7178     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 7186     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 7195     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9445     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 7196     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 7199     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 7200     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 7208     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 7215     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 7228     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 7242     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 7186     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 7199     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 7204     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 7227     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 7252     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 7227     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 7248     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 7237     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10771    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 7257     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 7250     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 7254     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 7258     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 7278     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 7285     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 7297     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 7309     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 7320     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 7330     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 7337     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11802    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 7340     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11873    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 7349     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11984    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 7359     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 7364     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 7373     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 7377     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 7352     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12434    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 7358     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 7367     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 7373     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 7374     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 7380     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 7398     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 7405     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 7414     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 7421     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 7417     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 7420     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 7417     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 7407     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 7429     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 7437     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 7439     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 7454     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 7460     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15901    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 7453     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 7460     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 7458     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16165    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 7470     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 7476     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 7467     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 7475     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 7485     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 7482     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 7496     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 7501     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 7490     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 7473     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 7454     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17218    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 7447     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 7440     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 7446     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 7433     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 7432     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 7432     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 7260     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 7245     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 7225     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 7227     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 7234     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 7241     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 7246     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 7253     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 7263     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 7255     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 7255     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 7261     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 7266     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 7267     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 7272     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 7280     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 7288     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 7280     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 7284     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 7291     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 7287     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 7289     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 7290     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 7294     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 7297     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 7298     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19980    |
# ----------------------------------
